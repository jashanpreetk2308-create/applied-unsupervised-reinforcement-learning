# %% [markdown]
# <a href="https://colab.research.google.com/github/jashanpreetk2308-create/applied-unsupervised-reinforcement-learning/blob/main/Deep_Learning_Fashion_Image_Classification_BBA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning Practical: Fashion Image Classification
#
# ## Google Colab Practical for BBA AI/ML Students
#
# ### Business Scenario
#
# Imagine that an e-commerce company receives thousands of product images every day.
#
# Instead of asking employees to manually identify every product, a Deep Learning model can help classify images into categories such as:
#
# - T-shirt / Top
# - Trouser
# - Pullover
# - Dress
# - Coat
# - Sandal
# - Shirt
# - Sneaker
# - Bag
# - Ankle Boot
#
# ### Learning Objectives
#
# By the end of this practical, students will be able to:
#
# - Understand how images can be used as input for Deep Learning.
# - Build a simple Artificial Neural Network.
# - Understand input, hidden and output layers.
# - Train a model on product images.
# - Check model accuracy.
# - Use the trained model to predict a product category.
# - Connect Deep Learning output with a business use case.
#
# > **Important:** You are not expected to memorize the Python code. Focus on understanding the steps and interpreting the output.

# %% [markdown]
# # Step 1: Import the Required Libraries
#
# We will use TensorFlow/Keras to create the neural network and Matplotlib to display images.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

print("TensorFlow version:", tf.__version__)

# %% [markdown]
# # Step 2: Load the Fashion Product Dataset
#
# We will use the **Fashion MNIST** dataset.
#
# It contains images of common fashion products such as shirts, shoes, bags and dresses.
#
# The dataset downloads automatically, so no manual file upload is required.

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

print("Training images:", train_images.shape)
print("Testing images:", test_images.shape)

# %% [markdown]
# # Step 3: Define the Product Categories
#
# The model uses numbers internally.
#
# We will connect those numbers to understandable product names.

# %%
class_names = [
    "T-shirt/Top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle Boot"
]

print(class_names)

# %% [markdown]
# # Step 4: Look at One Product Image
#
# Before training the model, let us see what one image looks like.

# %%
plt.imshow(train_images[0], cmap="gray")
plt.title("Product: " + class_names[train_labels[0]])
plt.axis("off")
plt.show()

# %% [markdown]
# ## Business Interpretation
#
# Each image is a piece of data.
#
# For an e-commerce company:
#
# **Input:** Product image
# **Expected Output:** Product category
#
# The goal of the neural network is to learn patterns from many labelled product images.

# %% [markdown]
# # Step 5: View Several Product Images

# %%
plt.figure(figsize=(10, 6))

for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.imshow(train_images[i], cmap="gray")
    plt.title(class_names[train_labels[i]])
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Step 6: Prepare the Images
#
# Image pixel values originally range from 0 to 255.
#
# We convert them to values between 0 and 1.
#
# You only need to understand that this makes the image data easier for the neural network to process.

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

print("Images are ready for training.")

# %% [markdown]
# # Step 7: Create a Simple Neural Network
#
# Our model has three main stages:
#
# ### Input
# The product image enters the network.
#
# ### Hidden Layer
# The network learns useful patterns.
#
# ### Output
# The model selects one of the 10 product categories.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])

model.summary()

# %% [markdown]
# ## Connect This to Theory
#
# The model contains:
#
# **Input → Hidden Layer → Output**
#
# - `Flatten` prepares the image for the network.
# - `Dense(64)` acts as a hidden layer.
# - `ReLU` is an activation function.
# - The final layer has 10 outputs because there are 10 product categories.
# - `Softmax` helps produce category probabilities.
#
# No mathematical calculation is required for this course.

# %% [markdown]
# # Step 8: Prepare the Model for Training

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

print("Model is ready for training.")

# %% [markdown]
# # Step 9: Train the Neural Network
#
# An **epoch** means the model has gone through the training dataset once.
#
# We will use only 3 epochs to keep the classroom demonstration quick.

# %%
history = model.fit(
    train_images,
    train_labels,
    epochs=3,
    validation_split=0.1
)

# %% [markdown]
# # Step 10: Check Model Accuracy
#
# Now we test the model on images it did not use for training.

# %%
test_loss, test_accuracy = model.evaluate(test_images, test_labels, verbose=0)

print("Test Accuracy:", round(test_accuracy * 100, 2), "%")

# %% [markdown]
# ## What Does Accuracy Mean Here?
#
# If the model shows, for example, **87% accuracy**, it means that approximately 87 out of every 100 test images were classified correctly.
#
# The exact result may vary slightly.
#
# ### Management Question
#
# Would accuracy alone be enough before a company deploys this system?
#
# Think about:
#
# - Cost of incorrect classification
# - Customer experience
# - Human review
# - Quality of training data

# %% [markdown]
# # Step 11: Ask the Model to Predict New Images

# %%
predictions = model.predict(test_images, verbose=0)

predicted_class = np.argmax(predictions[0])
actual_class = test_labels[0]

print("Predicted Product:", class_names[predicted_class])
print("Actual Product:", class_names[actual_class])

# %% [markdown]
# # Step 12: Display the Prediction

# %%
plt.imshow(test_images[0], cmap="gray")
plt.title(
    "Predicted: " + class_names[predicted_class] +
    "\nActual: " + class_names[actual_class]
)
plt.axis("off")
plt.show()

# %% [markdown]
# # Step 13: Test Another Product
#
# Change the value of `image_number` to try another image.
#
# For example:
#
# `image_number = 25`

# %%
image_number = 25

prediction = model.predict(
    np.expand_dims(test_images[image_number], axis=0),
    verbose=0
)

predicted_class = np.argmax(prediction)
actual_class = test_labels[image_number]

plt.imshow(test_images[image_number], cmap="gray")
plt.title(
    "Predicted: " + class_names[predicted_class] +
    "\nActual: " + class_names[actual_class]
)
plt.axis("off")
plt.show()

# %% [markdown]
# # Business Application
#
# Imagine this model is used by a fashion e-commerce company.
#
# ### Current Process
#
# Employee receives a product image.
#
# ↓
#
# Employee manually selects the product category.
#
# ↓
#
# Product is added to the website.
#
# ### AI-Assisted Process
#
# Product image is uploaded.
#
# ↓
#
# Deep Learning model analyzes the image.
#
# ↓
#
# Model predicts the product category.
#
# ↓
#
# Employee reviews the result if required.
#
# ↓
#
# Product is added to the website.
#
# ### Possible Business Benefits
#
# - Faster product listing
# - Reduced repetitive manual work
# - More consistent categorization
# - Better product-search experience
# - Ability to process larger numbers of images

# %% [markdown]
# # Student Activity
#
# Answer the following:
#
# 1. What was the input given to the Deep Learning model?
# 2. What was the output produced by the model?
# 3. What was the role of the hidden layer?
# 4. Which activation function was used in the hidden layer?
# 5. What was the test accuracy of your model?
# 6. Find one image that the model classified correctly.
# 7. Try several image numbers. Can you find an incorrect prediction?
# 8. Why could an incorrect product category create a business problem?
# 9. Where should human review be used?
# 10. Give one other business problem where image classification could be useful.

# %% [markdown]
# # Key Takeaways
#
# - Deep Learning can learn complex patterns from images.
# - Artificial Neural Networks contain input, hidden and output stages.
# - Training means learning from historical examples.
# - Testing checks performance on unseen examples.
# - A trained model can predict the category of a new image.
# - Model predictions are not always correct.
# - Businesses must consider accuracy, risk and human oversight before using AI systems.

# %% [markdown]
# # Final Reflection
#
# Complete the following in your own words:
#
# ### 1. Business Problem
# What business problem did this project solve?
#
# ### 2. AI Solution
# How did Deep Learning help solve the problem?
#
# ### 3. Business Benefit
# Mention two possible benefits for an e-commerce company.
#
# ### 4. Limitation
# Mention one limitation of the model.
#
# ### 5. Human Role
# Where should a human employee remain involved?

# %% [markdown]
# # Submission
#
# Rename your notebook as:
#
# `Deep_Learning_Fashion_Classification_Name.ipynb`
#
# Save one screenshot showing:
#
# - A product image
# - Predicted category
# - Actual category
#
# Upload the notebook and screenshot to your course GitHub repository.
#
# Suggested folder:
#
# `part-a/deep-learning/`
